# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf

AUTOTUNE = tf.data.experimental.AUTOTUNE
import IPython.display as display
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
import pathlib
data_dir = pathlib.Path("/tf/notebooks/tensorflow/tf2_tfrecord/train")

# %%
print(data_dir)
# Out:
# /tf/notebooks/tensorflow/tf2_tfrecord/train

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
image_count
# Out:
# 20

# %%
CLASS_NAMES = np.array([item.name for item in data_dir.glob('*') ])
CLASS_NAMES
# Out:
# array(['cat', 'dog'], dtype='<U3')

# %%
roses = list(data_dir.glob('cat/*'))
for image_path in roses[:3]:
    display.display(Image.open(str(image_path)))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x75 at 0x7F06791CBF28>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x75 at 0x7F0678EF5198>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=80x60 at 0x7F0678EF5198>

# %%
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
BATCH_SIZE = 4
IMG_HEIGHT = 75
IMG_WIDTH = 75
STEPS_PER_EPOCH = np.ceil(image_count/BATCH_SIZE)
STEPS_PER_EPOCH
# Out:
# 5.0

# %%
train_data_gen = image_generator.flow_from_directory(directory=str(data_dir),
                                                     batch_size=BATCH_SIZE,
                                                     shuffle=True,
                                                     target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                     classes = list(CLASS_NAMES))
# Out:
# Found 20 images belonging to 2 classes.

# %%
def show_batch(image_batch, label_batch):
  plt.figure(figsize=(10,10))
  for n in range(4):
      ax = plt.subplot(2,2,n+1)
      plt.imshow(image_batch[n])
      plt.title(CLASS_NAMES[label_batch[n]==1][0].title())
      plt.axis('off')

# %%
image_batch, label_batch = next(train_data_gen)
show_batch(image_batch, label_batch)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-a37cfc9a4881> in <module>
#       1 image_batch, label_batch = next(train_data_gen)
# ----> 2 show_batch(image_batch, label_batch)
#
# <ipython-input-25-92d42a5f4583> in show_batch(image_batch, label_batch)
#       2   plt.figure(figsize=(10,10))
#       3   for n in range(25):
# ----> 4       ax = plt.subplot(2,2,n+1)
#       5       plt.imshow(image_batch[n])
#       6       plt.title(CLASS_NAMES[label_batch[n]==1][0].title())
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1074
#    1075     fig = gcf()
# -> 1076     a = fig.add_subplot(*args, **kwargs)
#    1077     bbox = a.bbox
#    1078     byebye = []
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
#    1416         return self._add_axes_internal(key, a)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      57                 if num < 1 or num > rows*cols:
#      58                     raise ValueError(
# ---> 59                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      60                 self._subplotspec = GridSpec(
#      61                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 4, not 5
