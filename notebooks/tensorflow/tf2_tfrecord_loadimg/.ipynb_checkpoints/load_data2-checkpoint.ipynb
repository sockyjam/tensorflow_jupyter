# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf

AUTOTUNE = tf.data.experimental.AUTOTUNE
import IPython.display as display
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os
from tensorflow import keras

# %%
tf.__version__
# Out:
# '1.14.0'

# %%
import pathlib
data_dir = pathlib.Path("/home/socky/tensorflow_jupyter/notebooks/tensorflow/tf2_tfrecord_loadimg/train")

# %%
print(data_dir)
# Out:
# /home/socky/tensorflow_jupyter/notebooks/tensorflow/tf2_tfrecord_loadimg/train

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
image_count
# Out:
# 20

# %%
CLASS_NAMES = np.array([item.name for item in data_dir.glob('*') ])
CLASS_NAMES
# Out:
# array(['cat', 'dog'], dtype='<U3')

# %%
roses = list(data_dir.glob('cat/*'))
for image_path in roses[:3]:
    display.display(Image.open(str(image_path)))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x75 at 0x7F54CA8F75F8>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x75 at 0x7F54CA8F7668>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=80x60 at 0x7F54CA8F75F8>

# %%
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
BATCH_SIZE = 4
IMG_HEIGHT = 100
IMG_WIDTH = 100
STEPS_PER_EPOCH = np.ceil(image_count/BATCH_SIZE)
STEPS_PER_EPOCH
# Out:
# 5.0

# %%
train_data_gen = image_generator.flow_from_directory(directory=str(data_dir),
                                                     batch_size=BATCH_SIZE,
                                                     shuffle=True,
                                                     target_size=(IMG_HEIGHT, IMG_WIDTH),
                                                     classes = list(CLASS_NAMES))
# Out:
# Found 20 images belonging to 2 classes.

# %%
def show_batch(image_batch, label_batch):
  plt.figure(figsize=(10,10))
  for n in range(4):
      ax = plt.subplot(2,2,n+1)
      plt.imshow(image_batch[n])
      plt.title(CLASS_NAMES[label_batch[n]==1][0].title())
      plt.axis('off')

# %%
image_batch, label_batch = next(train_data_gen)
show_batch(image_batch, label_batch)

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# %%
len(image_batch)
# Out:
# 4
